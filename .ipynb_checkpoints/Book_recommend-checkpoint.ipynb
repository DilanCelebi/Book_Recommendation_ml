# %% [markdown]
# # Book recommendation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Books = pd.read_csv('Books.csv')
Ratings = pd.read_csv('Ratings.csv')
Users = pd.read_csv('Users.csv')

# %%
print(Books.shape)
print(Ratings.shape)
print(Users.shape)
# Out:
# (16790, 8)
# (1149780, 3)
# (278858, 3)

# %%
#Checking for missing values of Books

Books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            0
# Year-Of-Publication    1
# Publisher              1
# Image-URL-S            1
# Image-URL-M            1
# Image-URL-L            1
# dtype: int64

# %%
#Checking for missing values of Users and most likely we wont use age info

Users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
Ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
Users.duplicated().sum()
Ratings.duplicated().sum()
Books.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Popularity based Recommendation System

# %%
Ratings_with_BookName = Ratings.merge(Books,on = 'ISBN')

# %%
Ratings_with_BookName
# Out:
#         User-ID        ISBN  Book-Rating  \
# 0        276725  034545104X            0
# 1          2313  034545104X            5
# 2          6543  034545104X            0
# 3          8680  034545104X            5
# 4         10314  034545104X            9
# ...         ...         ...          ...
# 351631   216466  037312273X            0
# 351632   274308  037312273X            0
# 351633   178032  006008829X            8
# 351634   270838  006008829X           10
# 351635   227257  1576736261            0
#
#                                                Book-Title      Book-Author  \
# 0                                    Flesh Tones: A Novel       M. J. Rose
# 1                                    Flesh Tones: A Novel       M. J. Rose
# 2                                    Flesh Tones: A Novel       M. J. Rose
# 3                                    Flesh Tones: A Novel       M. J. Rose
# 4                                    Flesh Tones: A Novel       M. J. Rose
# ...                                                   ...              ...
# 351631  To Marry McAllister  (Bachelor Cousins) (Harle...  Carole Mortimer
# 351632  To Marry McAllister  (Bachelor Cousins) (Harle...  Carole Mortimer
# 351633  Choices: Taking Control of Your Life and Makin...   Melody Beattie
# 351634  Choices: Taking Control of Your Life and Makin...   Melody Beattie
# 351635             African Skies (Palisades Pure Romance)     Karen Rispin
#
#         Year-Of-Publication           Publisher  \
# 0                    2002.0    Ballantine Books
# 1                    2002.0    Ballantine Books
# 2                    2002.0    Ballantine Books
# 3                    2002.0    Ballantine Books
# 4                    2002.0    Ballantine Books
# ...                     ...                 ...
# 351631               2002.0           Harlequin
# 351632               2002.0           Harlequin
# 351633               2002.0  HarperSanFrancisco
# 351634               2002.0  HarperSanFrancisco
# 351635               2000.0           Multnomah
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/034545104X.0...
# 1       http://images.amazon.com/images/P/034545104X.0...
# 2       http://images.amazon.com/images/P/034545104X.0...
# 3       http://images.amazon.com/images/P/034545104X.0...
# 4       http://images.amazon.com/images/P/034545104X.0...
# ...                                                   ...
# 351631  http://images.amazon.com/images/P/037312273X.0...
# 351632  http://images.amazon.com/images/P/037312273X.0...
# 351633  http://images.amazon.com/images/P/006008829X.0...
# 351634  http://images.amazon.com/images/P/006008829X.0...
# 351635  http://images.amazon.com/images/P/1576736261.0...
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/034545104X.0...
# 1       http://images.amazon.com/images/P/034545104X.0...
# 2       http://images.amazon.com/images/P/034545104X.0...
# 3       http://images.amazon.com/images/P/034545104X.0...
# 4       http://images.amazon.com/images/P/034545104X.0...
# ...                                                   ...
# 351631  http://images.amazon.com/images/P/037312273X.0...
# 351632  http://images.amazon.com/images/P/037312273X.0...
# 351633  http://images.amazon.com/images/P/006008829X.0...
# 351634  http://images.amazon.com/images/P/006008829X.0...
# 351635  http://images.amazon.com/images/P/1576736261.0...
#
#                                               Image-URL-L
# 0       http://images.amazon.com/images/P/034545104X.0...
# 1       http://images.amazon.com/images/P/034545104X.0...
# 2       http://images.amazon.com/images/P/034545104X.0...
# 3       http://images.amazon.com/images/P/034545104X.0...
# 4       http://images.amazon.com/images/P/034545104X.0...
# ...                                                   ...
# 351631  http://images.amazon.com/images/P/037312273X.0...
# 351632  http://images.amazon.com/images/P/037312273X.0...
# 351633  http://images.amazon.com/images/P/006008829X.0...
# 351634  http://images.amazon.com/images/P/006008829X.0...
# 351635  http://images.amazon.com/images/P/1576736261.0...
#
# [351636 rows x 10 columns]

# %%
#Ratings_with_BookName["Book-Title"] = Ratings_with_BookName["Book-Title"].str.replace("[^a-zA-Z0-9]", " ", regex=True)

# %%
num_ratings_df= Ratings_with_BookName.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_ratings_df.rename(columns={'Book-Rating':'Num-Rating'},inplace=True)
num_ratings_df
# Out:
#                                            Book-Title  Num-Rating
# 0                                        It Takes Two           2
# 1                        Tales of Terror and Suspense           1
# 2                                                 '48           4
# 3                                        'Salem's Lot          32
# 4             .Hack: //Legend of the Twilight, Vol. 1           5
# ...                                               ...         ...
# 15825  metamorfosis, La (ClÃ¡sicos selecciÃ³n series)           3
# 15826                                        stardust          51
# 15827                Â¿QuiÃ©n se ha llevado mi queso?           2
# 15828                        Â¿QuÃ© me quieres, amor?           9
# 15829                           Ã?Â?ber die Freiheit.           1
#
# [15830 rows x 2 columns]

# %%
Ratings_with_BookName['Book-Rating'] = Ratings_with_BookName['Book-Rating'].astype(float)
avg_ratings_df = Ratings_with_BookName.groupby('Book-Title')['Book-Rating'].mean().reset_index()
avg_ratings_df.rename(columns={'Book-Rating':'Avg-Rating'},inplace=True)
avg_ratings_df
# Out:
#                                            Book-Title  Avg-Rating
# 0                                        It Takes Two    0.000000
# 1                        Tales of Terror and Suspense    0.000000
# 2                                                 '48    0.000000
# 3                                        'Salem's Lot    3.406250
# 4             .Hack: //Legend of the Twilight, Vol. 1    6.400000
# ...                                               ...         ...
# 15825  metamorfosis, La (ClÃ¡sicos selecciÃ³n series)    6.000000
# 15826                                        stardust    4.137255
# 15827                Â¿QuiÃ©n se ha llevado mi queso?    7.500000
# 15828                        Â¿QuÃ© me quieres, amor?    3.000000
# 15829                           Ã?Â?ber die Freiheit.    7.000000
#
# [15830 rows x 2 columns]

# %%
popular_df = num_ratings_df.merge(avg_ratings_df,on='Book-Title')
popular_df
# Out:
#                                            Book-Title  Num-Rating  Avg-Rating
# 0                                        It Takes Two           2    0.000000
# 1                        Tales of Terror and Suspense           1    0.000000
# 2                                                 '48           4    0.000000
# 3                                        'Salem's Lot          32    3.406250
# 4             .Hack: //Legend of the Twilight, Vol. 1           5    6.400000
# ...                                               ...         ...         ...
# 15825  metamorfosis, La (ClÃ¡sicos selecciÃ³n series)           3    6.000000
# 15826                                        stardust          51    4.137255
# 15827                Â¿QuiÃ©n se ha llevado mi queso?           2    7.500000
# 15828                        Â¿QuÃ© me quieres, amor?           9    3.000000
# 15829                           Ã?Â?ber die Freiheit.           1    7.000000
#
# [15830 rows x 3 columns]

# %%
# only keep books with at least 250 ratings
# sort by average rating in descending order
popular_df = popular_df[popular_df['Num-Rating']>=250].sort_values('Avg-Rating',ascending=False).head(50)
popular_df
# Out:
#                                               Book-Title  Num-Rating  \
# 5148   Harry Potter and the Prisoner of Azkaban (Book 3)         423
# 5146        Harry Potter and the Goblet of Fire (Book 4)         387
# 5149      Harry Potter and the Sorcerer's Stone (Book 1)         272
# 5147   Harry Potter and the Order of the Phoenix (Boo...         334
# 5145    Harry Potter and the Chamber of Secrets (Book 2)         556
# 12463  The Hobbit : The Enchanting Prelude to The Lor...         281
# 5150   Harry Potter and the Sorcerer's Stone (Harry P...         571
# 12145  The Fellowship of the Ring (The Lord of the Ri...         344
# 14513                              To Kill a Mockingbird         488
# 11853                                  The Da Vinci Code         887
# 12185                 The Five People You Meet in Heaven         427
# 11640                             The Catcher in the Rye         416
# 12851                          The Lovely Bones: A Novel        1295
# 49                                                  1984         256
# 9134                            Prodigal Summer: A Novel         253
# 4080                                      Fahrenheit 451         366
# 13607                            The Secret Life of Bees         715
# 14717  Tuesdays with Morrie: An Old Man, a Young Man,...         492
# 8118                                          Neverwhere         250
# 10762  Stupid White Men ...and Other Sorry Excuses fo...         283
# 13421                The Red Tent (Bestselling Backlist)         723
# 8155    Nickel and Dimed: On (Not) Getting By in America         335
# 4810                           Girl with a Pearl Earring         526
# 8622                                           Outlander         278
# 550                                       ANGELA'S ASHES         269
# 15353  Where the Heart Is (Oprah's Book Club (Paperba...         585
# 9865                      Seabiscuit: An American Legend         275
# 145    A Child Called \It\": One Child's Courage to S...         262
# 11319                                     The Bean Trees         389
# 6892                                          Life of Pi         643
# 4908                                         Good in Bed         490
# 12319    The Golden Compass (His Dark Materials, Book 1)         320
# 4171   Fast Food Nation: The Dark Side of the All-Ame...         321
# 6765   Left Behind: A Novel of the Earth's Last Days ...         297
# 821                                        American Gods         302
# 10268                                 Skipping Christmas         311
# 10871                       Suzanne's Diary for Nicholas         305
# 11726                                   The Color Purple         295
# 10000                  Seven Up (A Stephanie Plum Novel)         278
# 11195  The Alchemist: A Fable About Following Your Dream         266
# 5114   Hard Eight : A Stephanie Plum Novel (A Stephan...         266
# 362                              A Prayer for Owen Meany         412
# 14047   The Vampire Lestat (Vampire Chronicles, Book II)         301
# 15391       White Oleander : A Novel (Oprah's Book Club)         356
# 15441  Wicked: The Life and Times of the Wicked Witch...         326
# 14485                                           Timeline         530
# 7673                                              Misery         263
# 15170                                     Watership Down         259
# 928                                  Angels &amp; Demons         656
# 1362                                  Bel Canto: A Novel         350
#
#        Avg-Rating
# 5148     5.867612
# 5146     5.824289
# 5149     5.724265
# 5147     5.571856
# 5145     5.183453
# 12463    5.007117
# 5150     4.900175
# 12145    4.898256
# 14513    4.704918
# 11853    4.658399
# 12185    4.543326
# 11640    4.526442
# 12851    4.468726
# 49       4.460938
# 9134     4.450593
# 4080     4.409836
# 13607    4.381818
# 14717    4.363821
# 8118     4.360000
# 10762    4.356890
# 13421    4.334716
# 8155     4.289552
# 4810     4.218631
# 8622     4.136691
# 550      4.115242
# 15353    4.105983
# 9865     4.098182
# 145      4.091603
# 11319    4.087404
# 6892     4.073095
# 4908     4.055102
# 12319    4.053125
# 4171     4.037383
# 6765     4.026936
# 821      4.006623
# 10268    4.000000
# 10871    3.990164
# 11726    3.925424
# 10000    3.888489
# 11195    3.875940
# 5114     3.804511
# 362      3.781553
# 14047    3.777409
# 15391    3.772472
# 15441    3.766871
# 14485    3.764151
# 7673     3.752852
# 15170    3.745174
# 928      3.704268
# 1362     3.702857

# %%
popular_df = popular_df.merge(Books, on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','Num-Rating','Avg-Rating']]
popular_df['Image-URL-M'][0]
# Out:
# 'http://images.amazon.com/images/P/0439136350.01.MZZZZZZZ.jpg'

# %% [markdown]
# ## Collabrative Based Recommendation System

# %%
x = Ratings_with_BookName.groupby('User-ID').count()['Book-Rating'] > 100
similar_users = x[x].index

# %%
filtered_rating = Ratings_with_BookName[Ratings_with_BookName['User-ID'].isin(similar_users)]

# %%
y = filtered_rating.groupby('Book-Title').count()['Book-Rating'] >= 30
famous_books = y[y].index

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]
pt = final_ratings.pivot_table(index='Book-Title',columns = 'User-ID',values='Book-Rating')
pt
# Out:
# User-ID                                             254     507     882     \
# Book-Title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     0.0     NaN
# 2010: Odyssey Two                                      NaN     NaN     NaN
# 24 Hours                                               NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Wuthering Heights                                      NaN     NaN     NaN
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             1424    1435    1733    \
# Book-Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2010: Odyssey Two                                      NaN     NaN     NaN
# 24 Hours                                               NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Wuthering Heights                                      NaN     NaN     NaN
# Year of Wonders                                        7.0     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             1903    2033    2110    \
# Book-Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2010: Odyssey Two                                      NaN     NaN     NaN
# 24 Hours                                               NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Wuthering Heights                                      NaN     NaN     NaN
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     0.0     NaN
#
# User-ID                                             2276    ...  271448  \
# Book-Title                                                  ...
# 1984                                                   NaN  ...     NaN
# 1st to Die: A Novel                                    NaN  ...     NaN
# 2010: Odyssey Two                                      0.0  ...     NaN
# 24 Hours                                               NaN  ...     NaN
# 2nd Chance                                            10.0  ...     NaN
# ...                                                    ...  ...     ...
# Wuthering Heights                                      NaN  ...     NaN
# Year of Wonders                                        NaN  ...     NaN
# You Belong To Me                                       NaN  ...     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     NaN  ...     NaN
# \O\" Is for Outlaw"                                    NaN  ...     NaN
#
# User-ID                                             271705  273979  274004  \
# Book-Title
# 1984                                                  10.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2010: Odyssey Two                                      NaN     NaN     NaN
# 24 Hours                                               NaN     0.0     NaN
# 2nd Chance                                             NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Wuthering Heights                                      NaN     NaN     NaN
# Year of Wonders                                        NaN     9.0     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             274061  274301  274308  \
# Book-Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2010: Odyssey Two                                      NaN     NaN     NaN
# 24 Hours                                               NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     0.0
# ...                                                    ...     ...     ...
# Wuthering Heights                                      NaN     NaN     NaN
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     8.0     NaN
#
# User-ID                                             275970  277427  278418
# Book-Title
# 1984                                                   0.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2010: Odyssey Two                                      NaN     NaN     NaN
# 24 Hours                                               NaN    10.0     NaN
# 2nd Chance                                             NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Wuthering Heights                                      NaN     NaN     NaN
# Year of Wonders                                        0.0     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# [988 rows x 524 columns]

# %%
pt.fillna(0,inplace=True)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(pt)

# %%
similarity_scores.shape
# Out:
# (988, 988)

# %%
def recommend(book_name):
    
    # Convert book name to lower case
    book_name = book_name.lower()
    
    # Find books with matching (partial) titles
    matching_books = []
    for title in pt.index:
        if book_name in title.lower():
            matching_books.append(title)
    
    # Find similar items for each matching book
    data = []
    for book_title in matching_books:
        # Index fetch
        index = np.where(pt.index==book_title)[0][0]
        similar_items = sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1], reverse=True)[1:6]
    
        for i in similar_items:
            item = []
            temp_df = Books[Books['Book-Title'] == pt.index[i[0]]]
            item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
            item.extend([author.lower() for author in list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values)])
            item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
        
            data.append(item)
    
    return data

# %%
recommend('The Da Vinci Code')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 recommend('The Da Vinci Code')
#
# Cell In[24], line 38, in recommend(book_name)
#      35 pt.fillna(0,inplace=True)
#      37 # calculate similarity scores
# ---> 38 similarity_scores = cosine_similarity(pt)
#      40 # find index of input book title
#      41 book_index = filtered_books.index[filtered_books['Book-Title'].str.lower() == book_name][0]
#
# File ~/.local/lib/python3.10/site-packages/sklearn/metrics/pairwise.py:1393, in cosine_similarity(X, Y, dense_output)
#    1358 """Compute cosine similarity between samples in X and Y.
#    1359
#    1360 Cosine similarity, or the cosine kernel, computes similarity as the
#    (...)
#    1389     Returns the cosine similarity between samples in X and Y.
#    1390 """
#    1391 # to avoid recursive import
# -> 1393 X, Y = check_pairwise_arrays(X, Y)
#    1395 X_normalized = normalize(X, copy=True)
#    1396 if X is Y:
#
# File ~/.local/lib/python3.10/site-packages/sklearn/metrics/pairwise.py:146, in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, copy)
#     143     dtype = dtype_float
#     145 if Y is X or Y is None:
# --> 146     X = Y = check_array(
#     147         X,
#     148         accept_sparse=accept_sparse,
#     149         dtype=dtype,
#     150         copy=copy,
#     151         force_all_finite=force_all_finite,
#     152         estimator=estimator,
#     153     )
#     154 else:
#     155     X = check_array(
#     156         X,
#     157         accept_sparse=accept_sparse,
#    (...)
#     161         estimator=estimator,
#     162     )
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:931, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     929     n_samples = _num_samples(array)
#     930     if n_samples < ensure_min_samples:
# --> 931         raise ValueError(
#     932             "Found array with %d sample(s) (shape=%s) while a"
#     933             " minimum of %d is required%s."
#     934             % (n_samples, array.shape, ensure_min_samples, context)
#     935         )
#     937 if ensure_min_features > 0 and array.ndim == 2:
#     938     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required by check_pairwise_arrays.

# %%
import pickle
pickle.dump(popular_df,open('popular.pkl','wb'))

# %%
Books.drop_duplicates('Book-Title')

# %%
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(Books,open('books.pkl','wb'))
pickle.dump(similarity_scores,open('similarity_scores.pkl','wb'))
